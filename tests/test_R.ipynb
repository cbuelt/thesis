# %%
import numpy as np
import pandas as pd
import pyreadr
import os

# %%
result = pyreadr.read_r('../data/data_test/sim.RData')

# %%
result["brown"]
# Out:
# <xarray.DataArray (dim_0: 25, dim_1: 25, dim_2: 200)>
# array([[[ 2.07668558,  6.27326484,  1.42295785, ..., 10.06984185,
#           0.3273474 ,  1.24100557],
#         [ 0.68328392,  0.45740598,  6.94185862, ...,  1.56404125,
#           1.50741666,  1.97472354],
#         [ 1.15484032,  1.90654176,  1.55631372, ...,  0.77619053,
#           1.26143865,  0.89687298],
#         ...,
#         [ 1.31157876,  0.86942545, 48.92864902, ...,  8.21578619,
#           0.89587862,  0.74231089],
#         [ 0.27260467,  0.36815063, 15.8763069 , ...,  0.62929646,
#           1.61599535,  0.60713854],
#         [ 0.27532537,  0.59202067,  2.48876736, ...,  1.40857917,
#           0.7354236 ,  0.73883739]],
#
#        [[ 4.12619818,  3.25373136,  0.6978773 , ...,  2.58283064,
#           0.79633116,  5.38078104],
#         [ 1.32200011,  1.58473164,  2.56732634, ...,  3.14947421,
#           1.32985349,  2.55617854],
#         [ 0.9091239 ,  2.66424438,  3.3680143 , ...,  0.87248526,
# ...
